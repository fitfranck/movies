# %%
import pandas as pd

# %%
import requests as rq
import pandas as pd
from PIL import Image
import io
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dico_genre={'Action' :28,
'Adventure' :12,
'Animation' :16,
'Comedy':35,
'Crime':80,
'Documentary':99,
'Drama':18,
'Family':10751,
'Fantasy':14,
'History':36,
'Horror':27,
'Music':10402,
'Mystery':9648,
'Romance':10749,
'Science Fiction':878,
'TV Movie':10770,
'Thriller':53,
'War':10752,
'Western':37}

# %%
df = pd.read_csv('raw_data/movies.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [209], line 1
# ----> 1 df = pd.read_csv('raw_data/movies.csv')
#
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
len(df['original_title'].unique())
# Out:
# 91686

# %%
df = df.drop(columns='Unnamed: 0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [206], line 1
# ----> 1 df = df.drop(columns='Unnamed: 0')
#
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df = df.drop(columns='adult')

# %%
len(df)
# Out:
# 193498

# %%
df = df.drop_duplicates()

# %%
df = df.dropna(subset=['overview', 'poster_path'])

# %%
df.head(2)
# Out:
#                       backdrop_path      genre_ids   id original_language  \
# 0  /vKp3NvqBkcjHkCHSGi6EbcP7g4J.jpg  [12, 35, 878]  196                en
# 1  /aXKUodFZfaMMm2nM4rdekrNgvE2.jpg   [12, 18, 37]  581                en
#
#                 original_title  \
# 0  Back to the Future Part III
# 1           Dances with Wolves
#
#                                             overview popularity  \
# 0  The final installment of the Back to the Futur...     39.069
# 1  Wounded Civil War soldier, John Dunbar tries t...     30.701
#
#                         poster_path release_date                        title  \
# 0  /crzoVQnMzIrRfHtQw0tLBirNfVg.jpg   1990-05-25  Back to the Future Part III
# 1  /cvaBVpS0GzKqBd63pFT8f1E8OKv.jpg   1990-03-30           Dances with Wolves
#
#    ... is_horror is_music is_mystery is_romance is_science_fiction  \
# 0  ...     False    False      False      False               True
# 1  ...     False    False      False      False              False
#
# ...

# %%
df = df[df.is_principal != 10770]

# %%
df['poster_url'] = 'https://www.themoviedb.org/t/p/original/' + df['poster_path']

# %%
len(df['poster_url'])
# Out:
# 96253

# %%
df['id'] = df['id'].apply(lambda x: '{0:0>7}'.format(x))

# %%
df.drop(df[len(df['id'])>7])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# ...

# %%
df_1 = df[df['id'].map(len)<7]

# %%
df_1.head(2)
# Out:
# Empty DataFrame
# Columns: [backdrop_path, genre_ids, id, original_language, original_title, overview, popularity, poster_path, release_date, title, video, vote_average, vote_count, is_action, is_adventure, is_animation, is_comedy, is_crime, is_documentary, is_drama, is_family, is_fantasy, is_history, is_horror, is_music, is_mystery, is_romance, is_science_fiction, is_tv_movie, is_thriller, is_war, is_western, is_principal, poster_url]
# Index: []
#
# [0 rows x 34 columns]

# %%
for i in df['id']: 
    if len(i)>7:
        indexNames = df[ df['id'] == 'i' ].index
        # Delete these row indexes from dataFrame
        df.drop(indexNames , inplace=True)
# Out:
#   Cell In [212], line 3
#     print i
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
for i in range(1000):
    if df['id'][i]=='Dogtanian: The movie':
    
        
        indexNames = df[ df['id'] == 'i' ].index
        # Delete these row indexes from dataFrame
        df.drop(indexNames , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/movies/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 55
#
# ...

# %%
for i in df['id']:
    if df['id'][i][0]!='0' or df['id'][i][0]!='1' or df['id'][i][0]!='2' or df['id'][i][0]!='3' or df['id'][i][0]!='4' or df['id'][i][0]!='5' or df['id'][i][0]!='6' or df['id'][i][0]!='7' or df['id'][i][0]!='8' or df['id'][i][0]!='9':
        print i

# %%
list_=[]
for i in df['id']:
    list_.append(len(i))
list_
# Out:
# [7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  20,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
# ...

# %%
import tensorflow as tf

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
